# %%
import pandas as pd 

fed_files = ["MORTGAGE30US.csv", "RRVRUSQ156N.csv", "CPIAUCSL.csv" ]

dfs = [pd.read_csv(f,parse_dates=True, index_col=0)for f in fed_files]

# %%
dfs[0]
# Out:
#                   MORTGAGE30US
# observation_date
# 1971-04-02                7.33
# 1971-04-09                7.31
# 1971-04-16                7.31
# 1971-04-23                7.31
# 1971-04-30                7.29
# ...                        ...
# 2025-12-31                6.15
# 2026-01-08                6.16
# 2026-01-15                6.06
# 2026-01-22                6.09
# 2026-01-29                6.10
#
# [2862 rows x 1 columns]

# %%
dfs[1]
# Out:
#                   RRVRUSQ156N
# observation_date
# 1956-01-01                6.2
# 1956-04-01                5.9
# 1956-07-01                6.3
# 1956-10-01                5.8
# 1957-01-01                5.3
# ...                       ...
# 2024-07-01                6.9
# 2024-10-01                6.9
# 2025-01-01                7.1
# 2025-04-01                7.0
# 2025-07-01                7.1
#
# [279 rows x 1 columns]

# %%
dfs[2]
# Out:
#                   CPIAUCSL
# observation_date
# 1947-01-01          21.480
# 1947-02-01          21.620
# 1947-03-01          22.000
# 1947-04-01          22.000
# 1947-05-01          21.950
# ...                    ...
# 2025-08-01         323.364
# 2025-09-01         324.368
# 2025-10-01             NaN
# 2025-11-01         325.031
# 2025-12-01         326.030
#
# [948 rows x 1 columns]

# %%
fed_data = pd.concat(dfs, axis=1)

# %%
fed_data
# Out:
#                   MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# observation_date
# 1947-01-01                 NaN          NaN     21.48
# 1947-02-01                 NaN          NaN     21.62
# 1947-03-01                 NaN          NaN     22.00
# 1947-04-01                 NaN          NaN     22.00
# 1947-05-01                 NaN          NaN     21.95
# ...                        ...          ...       ...
# 2025-12-31                6.15          NaN       NaN
# 2026-01-08                6.16          NaN       NaN
# 2026-01-15                6.06          NaN       NaN
# 2026-01-22                6.09          NaN       NaN
# 2026-01-29                6.10          NaN       NaN
#
# [3723 rows x 3 columns]

# %%
fed_data.tail(50)
# Out:
#                   MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# observation_date
# 2025-04-10                6.62          NaN       NaN
# 2025-04-17                6.83          NaN       NaN
# 2025-04-24                6.81          NaN       NaN
# 2025-05-01                6.76          NaN   320.580
# 2025-05-08                6.76          NaN       NaN
# 2025-05-15                6.81          NaN       NaN
# 2025-05-22                6.86          NaN       NaN
# 2025-05-29                6.89          NaN       NaN
# 2025-06-01                 NaN          NaN   321.500
# 2025-06-05                6.85          NaN       NaN
# 2025-06-12                6.84          NaN       NaN
# 2025-06-18                6.81          NaN       NaN
# 2025-06-26                6.77          NaN       NaN
# 2025-07-01                 NaN          7.1   322.132
# 2025-07-03                6.67          NaN       NaN
# 2025-07-10                6.72          NaN       NaN
# 2025-07-17                6.75          NaN       NaN
# 2025-07-24                6.74          NaN       NaN
# 2025-07-31                6.72          NaN       NaN
# 2025-08-01                 NaN          NaN   323.364
# 2025-08-07                6.63          NaN       NaN
# 2025-08-14                6.58          NaN       NaN
# 2025-08-21                6.58          NaN       NaN
# 2025-08-28                6.56          NaN       NaN
# 2025-09-01                 NaN          NaN   324.368
# 2025-09-04                6.50          NaN       NaN
# 2025-09-11                6.35          NaN       NaN
# 2025-09-18                6.26          NaN       NaN
# 2025-09-25                6.30          NaN       NaN
# 2025-10-01                 NaN          NaN       NaN
# 2025-10-02                6.34          NaN       NaN
# 2025-10-09                6.30          NaN       NaN
# 2025-10-16                6.27          NaN       NaN
# 2025-10-23                6.19          NaN       NaN
# 2025-10-30                6.17          NaN       NaN
# 2025-11-01                 NaN          NaN   325.031
# 2025-11-06                6.22          NaN       NaN
# 2025-11-13                6.24          NaN       NaN
# 2025-11-20                6.26          NaN       NaN
# 2025-11-26                6.23          NaN       NaN
# 2025-12-01                 NaN          NaN   326.030
# 2025-12-04                6.19          NaN       NaN
# 2025-12-11                6.22          NaN       NaN
# 2025-12-18                6.21          NaN       NaN
# 2025-12-24                6.18          NaN       NaN
# 2025-12-31                6.15          NaN       NaN
# 2026-01-08                6.16          NaN       NaN
# 2026-01-15                6.06          NaN       NaN
# 2026-01-22                6.09          NaN       NaN
# 2026-01-29                6.10          NaN       NaN

# %%
fed_data = fed_data.ffill()

# %%
fed_data.tail(50)
# Out:
#                   MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# observation_date
# 2025-04-10                6.62          7.0   320.321
# 2025-04-17                6.83          7.0   320.321
# 2025-04-24                6.81          7.0   320.321
# 2025-05-01                6.76          7.0   320.580
# 2025-05-08                6.76          7.0   320.580
# 2025-05-15                6.81          7.0   320.580
# 2025-05-22                6.86          7.0   320.580
# 2025-05-29                6.89          7.0   320.580
# 2025-06-01                6.89          7.0   321.500
# 2025-06-05                6.85          7.0   321.500
# 2025-06-12                6.84          7.0   321.500
# 2025-06-18                6.81          7.0   321.500
# 2025-06-26                6.77          7.0   321.500
# 2025-07-01                6.77          7.1   322.132
# 2025-07-03                6.67          7.1   322.132
# 2025-07-10                6.72          7.1   322.132
# 2025-07-17                6.75          7.1   322.132
# 2025-07-24                6.74          7.1   322.132
# 2025-07-31                6.72          7.1   322.132
# 2025-08-01                6.72          7.1   323.364
# 2025-08-07                6.63          7.1   323.364
# 2025-08-14                6.58          7.1   323.364
# 2025-08-21                6.58          7.1   323.364
# 2025-08-28                6.56          7.1   323.364
# 2025-09-01                6.56          7.1   324.368
# 2025-09-04                6.50          7.1   324.368
# 2025-09-11                6.35          7.1   324.368
# 2025-09-18                6.26          7.1   324.368
# 2025-09-25                6.30          7.1   324.368
# 2025-10-01                6.30          7.1   324.368
# 2025-10-02                6.34          7.1   324.368
# 2025-10-09                6.30          7.1   324.368
# 2025-10-16                6.27          7.1   324.368
# 2025-10-23                6.19          7.1   324.368
# 2025-10-30                6.17          7.1   324.368
# 2025-11-01                6.17          7.1   325.031
# 2025-11-06                6.22          7.1   325.031
# 2025-11-13                6.24          7.1   325.031
# 2025-11-20                6.26          7.1   325.031
# 2025-11-26                6.23          7.1   325.031
# 2025-12-01                6.23          7.1   326.030
# 2025-12-04                6.19          7.1   326.030
# 2025-12-11                6.22          7.1   326.030
# 2025-12-18                6.21          7.1   326.030
# 2025-12-24                6.18          7.1   326.030
# 2025-12-31                6.15          7.1   326.030
# 2026-01-08                6.16          7.1   326.030
# 2026-01-15                6.06          7.1   326.030
# 2026-01-22                6.09          7.1   326.030
# 2026-01-29                6.10          7.1   326.030

# %%
zillow_files = ["Metro_median_sale_price_uc_sfrcondo_sm_week.csv" , "Metro_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv"]

# %%
dfs = [pd.read_csv(f) for f in zillow_files]

# %%
dfs[0]
# Out:
#      RegionID  SizeRank             RegionName RegionType StateName  \
# 0      102001         0          United States    country       NaN
# 1      394913         1           New York, NY        msa        NY
# 2      753899         2        Los Angeles, CA        msa        CA
# 3      394463         3            Chicago, IL        msa        IL
# 4      394514         4             Dallas, TX        msa        TX
# ..        ...       ...                    ...        ...       ...
# 210    394720       268         Janesville, WI        msa        WI
# 211    395079       274          Sebastian, FL        msa        FL
# 212    394639       280     Grand Junction, CO        msa        CO
# 213    394685       289  Homosassa Springs, FL        msa        FL
# 214    394674       467              Heber, UT        msa        UT
#
#      2008-02-23  2008-03-01  2008-03-08  2008-03-15  2008-03-22  ...  \
# 0      169725.0    169725.0    171100.0    172350.0    174625.0  ...
# 1      399164.0    398914.0    395454.0    391250.0    390000.0  ...
# 2      467750.0    470000.0    470000.0    468500.0    458625.0  ...
# 3      216750.0    216375.0    213000.0    211500.0    214750.0  ...
# 4      136250.0    137000.0    140750.0    141500.0    141919.0  ...
# ..          ...         ...         ...         ...         ...  ...
# 210         NaN         NaN         NaN         NaN         NaN  ...
# 211         NaN         NaN         NaN         NaN         NaN  ...
# 212         NaN         NaN         NaN         NaN         NaN  ...
# 213         NaN         NaN         NaN         NaN         NaN  ...
# 214         NaN         NaN         NaN         NaN         NaN  ...
#
#      2025-10-11  2025-10-18  2025-10-25  2025-11-01  2025-11-08  2025-11-15  \
# 0      361250.0    363500.0    364750.0    364750.0    366000.0    366250.0
# 1      652300.0    652300.0    653550.0    656675.0    658125.0    661875.0
# 2      960438.0    960438.0    949188.0    935438.0    930000.0    935750.0
# 3      324000.0    327250.0    329313.0    327938.0    330438.0    330438.0
# 4      379655.0    380625.0    380750.0    379500.0    377375.0    374125.0
# ..          ...         ...         ...         ...         ...         ...
# 210    259025.0    244063.0    254050.0    256975.0    261725.0    270975.0
# 211    348500.0    348500.0    340688.0    345313.0    351813.0    371813.0
# 212    407269.0    401706.0    400081.0    409650.0    385875.0    393875.0
# 213    260413.0    259038.0    253175.0    257875.0    265125.0    262000.0
# 214   1206845.0   1169345.0   1164345.0   1103095.0   1059797.0   1078547.0
#
#      2025-11-22  2025-11-29  2025-12-06  2025-12-13
# 0      365725.0    361975.0    362725.0    360725.0
# 1      665625.0    662500.0    663750.0    661250.0
# 2      936000.0    942250.0    938750.0    936750.0
# 3      328875.0    325688.0    326938.0    328938.0
# 4      376075.0    373181.0    376220.0    374970.0
# ..          ...         ...         ...         ...
# 210    283488.0    276813.0    285438.0    294688.0
# 211    372750.0    373125.0    362750.0    346500.0
# 212    404125.0    392288.0    396963.0    381838.0
# 213    262250.0    254500.0    245900.0    259650.0
# 214   1034797.0    971047.0   1076250.0   1152546.0
#
# [215 rows x 935 columns]

# %%
dfs = [pd.DataFrame(df.iloc[0,5:]) for df in dfs]

# %%
dfs[0]
# Out:
#                    0
# 2008-02-23  169725.0
# 2008-03-01  169725.0
# 2008-03-08  171100.0
# 2008-03-15  172350.0
# 2008-03-22  174625.0
# ...              ...
# 2025-11-15  366250.0
# 2025-11-22  365725.0
# 2025-11-29  361975.0
# 2025-12-06  362725.0
# 2025-12-13  360725.0
#
# [930 rows x 1 columns]

# %%
dfs[1]
# Out:
#                         0
# 2000-01-31  120438.319923
# 2000-02-29  120650.209537
# 2000-03-31  120912.983858
# 2000-04-30  121476.583196
# 2000-05-31  122125.218463
# ...                   ...
# 2025-08-31  355166.149594
# 2025-09-30  355403.981336
# 2025-10-31  355831.508982
# 2025-11-30  356496.909241
# 2025-12-31  357275.367233
#
# [312 rows x 1 columns]

# %%
for df in dfs:
    df.index = pd.to_datetime(df.index)
    df["month"] = df.index.to_period("M")

# %%
dfs[1]
# Out:
#                         0    month
# 2000-01-31  120438.319923  2000-01
# 2000-02-29  120650.209537  2000-02
# 2000-03-31  120912.983858  2000-03
# 2000-04-30  121476.583196  2000-04
# 2000-05-31  122125.218463  2000-05
# ...                   ...      ...
# 2025-08-31  355166.149594  2025-08
# 2025-09-30  355403.981336  2025-09
# 2025-10-31  355831.508982  2025-10
# 2025-11-30  356496.909241  2025-11
# 2025-12-31  357275.367233  2025-12
#
# [312 rows x 2 columns]

# %%
price_data = dfs[0].merge(dfs[1], on="month")

# %%
price_data.index = dfs[0].index

# %%
price_data
# Out:
#                  0_x    month            0_y
# 2008-02-23  169725.0  2008-02  199185.647275
# 2008-03-01  169725.0  2008-03  197862.153363
# 2008-03-08  171100.0  2008-03  197862.153363
# 2008-03-15  172350.0  2008-03  197862.153363
# 2008-03-22  174625.0  2008-03  197862.153363
# ...              ...      ...            ...
# 2025-11-15  366250.0  2025-11  356496.909241
# 2025-11-22  365725.0  2025-11  356496.909241
# 2025-11-29  361975.0  2025-11  356496.909241
# 2025-12-06  362725.0  2025-12  357275.367233
# 2025-12-13  360725.0  2025-12  357275.367233
#
# [930 rows x 3 columns]

# %%
del price_data["month"]
price_data.columns=["price", "value"]

# %%
price_data
# Out:
#                price          value
# 2008-02-23  169725.0  199185.647275
# 2008-03-01  169725.0  197862.153363
# 2008-03-08  171100.0  197862.153363
# 2008-03-15  172350.0  197862.153363
# 2008-03-22  174625.0  197862.153363
# ...              ...            ...
# 2025-11-15  366250.0  356496.909241
# 2025-11-22  365725.0  356496.909241
# 2025-11-29  361975.0  356496.909241
# 2025-12-06  362725.0  357275.367233
# 2025-12-13  360725.0  357275.367233
#
# [930 rows x 2 columns]

# %%
fed_data = fed_data.dropna()

# %%
fed_data
# Out:
#                   MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# observation_date
# 1971-04-02                7.33          5.3     40.10
# 1971-04-09                7.31          5.3     40.10
# 1971-04-16                7.31          5.3     40.10
# 1971-04-23                7.31          5.3     40.10
# 1971-04-30                7.29          5.3     40.10
# ...                        ...          ...       ...
# 2025-12-31                6.15          7.1    326.03
# 2026-01-08                6.16          7.1    326.03
# 2026-01-15                6.06          7.1    326.03
# 2026-01-22                6.09          7.1    326.03
# 2026-01-29                6.10          7.1    326.03
#
# [3431 rows x 3 columns]

# %%
from datetime import timedelta

fed_data.index = fed_data.index + timedelta(days=2)

# %%
fed_data
# Out:
#                   MORTGAGE30US  RRVRUSQ156N  CPIAUCSL
# observation_date
# 1971-04-04                7.33          5.3     40.10
# 1971-04-11                7.31          5.3     40.10
# 1971-04-18                7.31          5.3     40.10
# 1971-04-25                7.31          5.3     40.10
# 1971-05-02                7.29          5.3     40.10
# ...                        ...          ...       ...
# 2026-01-02                6.15          7.1    326.03
# 2026-01-10                6.16          7.1    326.03
# 2026-01-17                6.06          7.1    326.03
# 2026-01-24                6.09          7.1    326.03
# 2026-01-31                6.10          7.1    326.03
#
# [3431 rows x 3 columns]

# %%
price_data = fed_data.merge(price_data, left_index=True, right_index=True)

# %%
price_data
# Out:
#             MORTGAGE30US  RRVRUSQ156N  CPIAUCSL     price          value
# 2008-02-23          6.04         10.1   212.687  169725.0  199185.647275
# 2008-03-01          6.24         10.1   212.687  169725.0  197862.153363
# 2008-03-08          6.03         10.1   213.448  171100.0  197862.153363
# 2008-03-15          6.13         10.1   213.448  172350.0  197862.153363
# 2008-03-22          5.87         10.1   213.448  174625.0  197862.153363
# ...                  ...          ...       ...       ...            ...
# 2025-11-08          6.22          7.1   325.031  366000.0  356496.909241
# 2025-11-15          6.24          7.1   325.031  366250.0  356496.909241
# 2025-11-22          6.26          7.1   325.031  365725.0  356496.909241
# 2025-12-06          6.19          7.1   326.030  362725.0  357275.367233
# 2025-12-13          6.22          7.1   326.030  360725.0  357275.367233
#
# [905 rows x 5 columns]

# %%
price_data.columns = ["interest", "vacancy", "cpi", "price", "value"]

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value
# 2008-02-23      6.04     10.1  212.687  169725.0  199185.647275
# 2008-03-01      6.24     10.1  212.687  169725.0  197862.153363
# 2008-03-08      6.03     10.1  213.448  171100.0  197862.153363
# 2008-03-15      6.13     10.1  213.448  172350.0  197862.153363
# 2008-03-22      5.87     10.1  213.448  174625.0  197862.153363
# ...              ...      ...      ...       ...            ...
# 2025-11-08      6.22      7.1  325.031  366000.0  356496.909241
# 2025-11-15      6.24      7.1  325.031  366250.0  356496.909241
# 2025-11-22      6.26      7.1  325.031  365725.0  356496.909241
# 2025-12-06      6.19      7.1  326.030  362725.0  357275.367233
# 2025-12-13      6.22      7.1  326.030  360725.0  357275.367233
#
# [905 rows x 5 columns]

# %%
price_data.plot.line(y="price", use_index = True)
# Out:
# <Axes: >

# %%
price_data["adj_price"] = price_data["price"]/price_data["cpi"] * 100

# %%
price_data.plot.line(y="adj_price", use_index=True)
# Out:
# <Axes: >

# %%
price_data["adj_value"] = price_data["value"] / price_data["cpi"] * 100

# %%
price_data["next_quarter"] = price_data["adj_price"].shift(-13)

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-23      6.04     10.1  212.687  169725.0  199185.647275
# 2008-03-01      6.24     10.1  212.687  169725.0  197862.153363
# 2008-03-08      6.03     10.1  213.448  171100.0  197862.153363
# 2008-03-15      6.13     10.1  213.448  172350.0  197862.153363
# 2008-03-22      5.87     10.1  213.448  174625.0  197862.153363
# ...              ...      ...      ...       ...            ...
# 2025-11-08      6.22      7.1  325.031  366000.0  356496.909241
# 2025-11-15      6.24      7.1  325.031  366250.0  356496.909241
# 2025-11-22      6.26      7.1  325.031  365725.0  356496.909241
# 2025-12-06      6.19      7.1  326.030  362725.0  357275.367233
# 2025-12-13      6.22      7.1  326.030  360725.0  357275.367233
#
#                 adj_price      adj_value  next_quarter
# 2008-02-23   79800.363915    93652.00848  82768.763243
# 2008-03-01   79800.363915   93029.735415  83233.429984
# 2008-03-08   80160.038979   92698.059182  82945.144691
# 2008-03-15   80745.661707   92698.059182  83060.106777
# 2008-03-22   81811.495071   92698.059182  83807.360333
# ...                   ...            ...           ...
# 2025-11-08  112604.643865   109680.89482          None
# 2025-11-15  112681.559605   109680.89482          None
# 2025-11-22   112520.03655   109680.89482          None
# 2025-12-06  111255.099224  109583.586551          None
# 2025-12-13  110641.658743  109583.586551          None
#
# [905 rows x 8 columns]

# %%
price_data.dropna(inplace=True)

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-23      6.04     10.1  212.687  169725.0  199185.647275
# 2008-03-01      6.24     10.1  212.687  169725.0  197862.153363
# 2008-03-08      6.03     10.1  213.448  171100.0  197862.153363
# 2008-03-15      6.13     10.1  213.448  172350.0  197862.153363
# 2008-03-22      5.87     10.1  213.448  174625.0  197862.153363
# ...              ...      ...      ...       ...            ...
# 2025-08-09      6.63      7.1  323.364  369125.0  355166.149594
# 2025-08-16      6.58      7.1  323.364  367875.0  355166.149594
# 2025-08-23      6.58      7.1  323.364  367875.0  355166.149594
# 2025-08-30      6.56      7.1  323.364  367500.0  355166.149594
# 2025-09-06      6.50      7.1  324.368  367500.0  355403.981336
#
#                 adj_price      adj_value   next_quarter
# 2008-02-23   79800.363915    93652.00848   82768.763243
# 2008-03-01   79800.363915   93029.735415   83233.429984
# 2008-03-08   80160.038979   92698.059182   82945.144691
# 2008-03-15   80745.661707   92698.059182   83060.106777
# 2008-03-22   81811.495071   92698.059182   83807.360333
# ...                   ...            ...            ...
# 2025-08-09   114151.54439  109834.783586  112604.643865
# 2025-08-16  113764.983115  109834.783586  112681.559605
# 2025-08-23  113764.983115  109834.783586   112520.03655
# 2025-08-30  113649.014733  109834.783586  111255.099224
# 2025-09-06  113297.242638  109568.139069  110641.658743
#
# [892 rows x 8 columns]

# %%
price_data["change"] = (price_data["next_quarter"] > price_data["adj_price"]).astype(int)

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-23      6.04     10.1  212.687  169725.0  199185.647275
# 2008-03-01      6.24     10.1  212.687  169725.0  197862.153363
# 2008-03-08      6.03     10.1  213.448  171100.0  197862.153363
# 2008-03-15      6.13     10.1  213.448  172350.0  197862.153363
# 2008-03-22      5.87     10.1  213.448  174625.0  197862.153363
# ...              ...      ...      ...       ...            ...
# 2025-08-09      6.63      7.1  323.364  369125.0  355166.149594
# 2025-08-16      6.58      7.1  323.364  367875.0  355166.149594
# 2025-08-23      6.58      7.1  323.364  367875.0  355166.149594
# 2025-08-30      6.56      7.1  323.364  367500.0  355166.149594
# 2025-09-06      6.50      7.1  324.368  367500.0  355403.981336
#
#                 adj_price      adj_value   next_quarter  change
# 2008-02-23   79800.363915    93652.00848   82768.763243       1
# 2008-03-01   79800.363915   93029.735415   83233.429984       1
# 2008-03-08   80160.038979   92698.059182   82945.144691       1
# 2008-03-15   80745.661707   92698.059182   83060.106777       1
# 2008-03-22   81811.495071   92698.059182   83807.360333       1
# ...                   ...            ...            ...     ...
# 2025-08-09   114151.54439  109834.783586  112604.643865       0
# 2025-08-16  113764.983115  109834.783586  112681.559605       0
# 2025-08-23  113764.983115  109834.783586   112520.03655       0
# 2025-08-30  113649.014733  109834.783586  111255.099224       0
# 2025-09-06  113297.242638  109568.139069  110641.658743       0
#
# [892 rows x 9 columns]

# %%
price_data["change"].value_counts()
# Out:
# change
# 0    480
# 1    412
# Name: count, dtype: int64

# %%
predictors =["interest", "vacancy", "adj_price", "adj_value"]
target = "change"

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import numpy as np

# %%
Start = 260
Step = 52

def prediction(train, test, predictors, target):
    rf = RandomForestClassifier(min_samples_split=10, random_state=1)
    rf.fit(train[predictors], train[target])
    preds = rf.predict(test[predictors])
    return preds

def backtest(data, predictors, target):
    all_preds=[]
    for i in range(Start, data.shape[0], Step):
        train = price_data.iloc[:i]
        test = price_data.iloc[i:(i+Step)]
        all_preds.append(prediction(train, test, predictors, target))
    
    preds = np.concatenate(all_preds)
    return preds, accuracy_score(data.iloc[Start:][target], preds)

# %%
preds, accuracy = backtest(price_data, predictors, target)

# %%
accuracy
# Out:
# 0.5933544303797469

# %%
yearly = price_data.rolling(52, min_periods=1).mean()

# %%
yearly
# Out:
#             interest    vacancy         cpi          price          value  \
# 2008-02-23  6.040000  10.100000  212.687000  169725.000000  199185.647275
# 2008-03-01  6.140000  10.100000  212.687000  169725.000000  198523.900319
# 2008-03-08  6.103333  10.100000  212.940667  170183.333333  198303.318000
# 2008-03-15  6.110000  10.100000  213.067500  170725.000000  198193.026841
# 2008-03-22  6.062000  10.100000  213.143600  171505.000000  198126.852145
# ...              ...        ...         ...            ...            ...
# 2025-08-09  6.674231   6.996154  318.525692  357641.653846  356275.320231
# 2025-08-16  6.671346   7.000000  318.703250  357741.461538  356286.380162
# 2025-08-23  6.673462   7.003846  318.880808  357889.346154  356297.440093
# 2025-08-30  6.674808   7.007692  319.058365  358042.711538  356308.500024
# 2025-09-06  6.675577   7.011538  319.255231  358196.076923  356324.133642
#
#                 adj_price      adj_value   next_quarter    change
# 2008-02-23   79800.363915   93652.008480   82768.763243  1.000000
# 2008-03-01   79800.363915   93340.871947   83001.096614  1.000000
# 2008-03-08   79920.255603   93126.601026   82982.445973  1.000000
# 2008-03-15   80126.607129   93019.465565   83001.861174  1.000000
# 2008-03-22   80463.584717   92955.184288   83162.961006  1.000000
# ...                   ...            ...            ...       ...
# 2025-08-09  112277.059731  111858.102073  112137.549299  0.442308
# 2025-08-16  112244.528466  111799.540462  112142.622248  0.442308
# 2025-08-23  112227.301938  111740.978850  112149.115763  0.442308
# 2025-08-30  112211.885700  111682.417239  112137.360611  0.442308
# 2025-09-06  112189.704614  111618.727848  112121.404842  0.442308
#
# [892 rows x 9 columns]

# %%
yearly_ratios = [p +"_year" for p in predictors]
price_data[yearly_ratios] = price_data[predictors] / yearly[predictors]

# %%
price_data
# Out:
#             interest  vacancy      cpi     price          value  \
# 2008-02-23      6.04     10.1  212.687  169725.0  199185.647275
# 2008-03-01      6.24     10.1  212.687  169725.0  197862.153363
# 2008-03-08      6.03     10.1  213.448  171100.0  197862.153363
# 2008-03-15      6.13     10.1  213.448  172350.0  197862.153363
# 2008-03-22      5.87     10.1  213.448  174625.0  197862.153363
# ...              ...      ...      ...       ...            ...
# 2025-08-09      6.63      7.1  323.364  369125.0  355166.149594
# 2025-08-16      6.58      7.1  323.364  367875.0  355166.149594
# 2025-08-23      6.58      7.1  323.364  367875.0  355166.149594
# 2025-08-30      6.56      7.1  323.364  367500.0  355166.149594
# 2025-09-06      6.50      7.1  324.368  367500.0  355403.981336
#
#                 adj_price      adj_value   next_quarter  change  \
# 2008-02-23   79800.363915    93652.00848   82768.763243       1
# 2008-03-01   79800.363915   93029.735415   83233.429984       1
# 2008-03-08   80160.038979   92698.059182   82945.144691       1
# 2008-03-15   80745.661707   92698.059182   83060.106777       1
# 2008-03-22   81811.495071   92698.059182   83807.360333       1
# ...                   ...            ...            ...     ...
# 2025-08-09   114151.54439  109834.783586  112604.643865       0
# 2025-08-16  113764.983115  109834.783586  112681.559605       0
# 2025-08-23  113764.983115  109834.783586   112520.03655       0
# 2025-08-30  113649.014733  109834.783586  111255.099224       0
# 2025-09-06  113297.242638  109568.139069  110641.658743       0
#
#             interest_year  vacancy_year adj_price_year adj_value_year
# 2008-02-23       1.000000      1.000000            1.0            1.0
# 2008-03-01       1.016287      1.000000            1.0       0.996667
# 2008-03-08       0.987985      1.000000          1.003       0.995398
# 2008-03-15       1.003273      1.000000       1.007726       0.996545
# 2008-03-22       0.968327      1.000000       1.016752       0.997234
# ...                   ...           ...            ...            ...
# 2025-08-09       0.993373      1.014843       1.016695       0.981912
# 2025-08-16       0.986308      1.014286       1.013546       0.982426
# 2025-08-23       0.985995      1.013729       1.013701       0.982941
# 2025-08-30       0.982800      1.013172       1.012807       0.983456
# 2025-09-06       0.973699      1.012617       1.009872       0.981629
#
# [892 rows x 13 columns]

# %%
perds ,accuracy = backtest(price_data, predictors + yearly_ratios, target)

# %%
accuracy
# Out:
# 0.6060126582278481

# %%
preds_match = (preds == price_data[target].iloc[Start:])

# %%
preds_match[preds_match == True] = "green"
preds_match[preds_match == False] = 'red'
# Out:
# /var/folders/pf/x4fqkrpj6gsfmrqwm4d34y300000gn/T/ipykernel_71687/3380439201.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'green' has dtype incompatible with bool, please explicitly cast to a compatible dtype first.
#   preds_match[preds_match == True] = "green"

# %%
import matplotlib.pyplot as plt

plot_data = price_data.iloc[Start:].copy()

# %%
plot_data.reset_index().plot.scatter(x="index",y="adj_price", color=preds_match )
# Out:
# <Axes: xlabel='index', ylabel='adj_price'>

# %%
from sklearn.inspection import permutation_importance

rf = RandomForestClassifier(min_samples_split=10, random_state=1)
rf.fit(price_data[predictors], price_data[target])

result = permutation_importance(rf, price_data[predictors],price_data[target], n_repeats=10, random_state=1)

# %%
result['importances_mean']
# Out:
# array([0.14304933, 0.1146861 , 0.29517937, 0.34316143])

# %%
predictors
# Out:
# ['interest', 'vacancy', 'adj_price', 'adj_value']
